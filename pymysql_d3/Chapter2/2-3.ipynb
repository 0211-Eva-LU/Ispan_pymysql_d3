# %%
import pymysql
from configparser import ConfigParser

config = ConfigParser()
config.read('../Chapter1/config.ini')

connection = pymysql.connect(
    host=config.get('DB', 'host'),
    user=config.get('DB', 'user'),
    password=config.get('DB', 'password'),
    port=config.getint('DB', 'port'),
    cursorclass=pymysql.cursors.DictCursor,
    db='chapter2',
)

with connection.cursor() as cursor:
    sql = """
    SELECT * FROM users;
    """
    cursor.execute(sql)
    result = cursor.fetchall()

print(result)

# %%
# %%time
from sql_utils import MySQLManager
import random

msql = MySQLManager('chapter2')
# 使用 function 寫入多個使用者

for i in range(90):
        name = f'user_{i}'
        username = f'{name}_{random.randint(10,9999)}' # 隨機生成使用者名稱、年齡和密碼
        age = random.randint(15,65)
        password = f'password_{random.randint(1000,9999)}'

        msql.add_user(name,age,username,password)
# Out:
# 資料建立完成
# 資料建立完成
# 資料建立完成
# 資料建立完成
# 資料建立完成
# 資料建立完成
# 資料建立完成
# 資料建立完成
# 資料建立完成
# 資料建立完成
# 資料建立完成
# 資料建立完成
# 資料建立完成
# 資料建立完成
# 資料建立完成
# 資料建立完成
# 資料建立完成
# 資料建立完成
# 資料建立完成
# 資料建立完成
# 資料建立完成
# 資料建立完成
# 資料建立完成
# 資料建立完成
# 資料建立完成
# 資料建立完成
# 資料建立完成
# 資料建立完成
# 資料建立完成
# 資料建立完成
# 資料建立完成
# 資料建立完成
# 資料建立完成
# 資料建立完成
# 資料建立完成
# 資料建立完成
# 資料建立完成
# 資料建立完成
# 資料建立完成
# 資料建立完成
# 資料建立完成
# 資料建立完成
# 資料建立完成
# 資料建立完成
# 資料建立完成
# 資料建立完成
# 資料建立完成
# 資料建立完成
# 資料建立完成
# 資料建立完成
# 資料建立完成
# 資料建立完成
# 資料建立完成
# 資料建立完成
# 資料建立完成
# 資料建立完成
# 資料建立完成
# 資料建立完成
# 資料建立完成
# 資料建立完成
# 資料建立完成
# 資料建立完成
# 資料建立完成
# 資料建立完成
# 資料建立完成
# 資料建立完成
# 資料建立完成
# 資料建立完成
# 資料建立完成
# 資料建立完成
# 資料建立完成
# 資料建立完成
# 資料建立完成
# 資料建立完成
# 資料建立完成
# 資料建立完成
# 資料建立完成
# 資料建立完成
# 資料建立完成
# 資料建立完成
# 資料建立完成
# 資料建立完成
# 資料建立完成
# 資料建立完成
# 資料建立完成
# 資料建立完成
# 資料建立完成
# 資料建立完成
# 資料建立完成
# 資料建立完成
# CPU times: total: 0 ns
# Wall time: 214 ms

# %% [markdown]
# `executemany(sql, list)`

# %%
# %%time

# 產生以下資料
"""
[('user_101', 121, 'user_101', 'password_101'), ('user_102', 122, 'user_102', 'password_102'), ...]
"""
with connection.cursor() as cursor:
sql = """
    INSERT INTO user (name,age,usernmae,password)
    VALUES (%s,%s,%s,%s)
"""
cursor.excutemany(sql,user_list) # -- >這個效率比較好
connection.commit()
# 使用 executemany() 批次新增資料
