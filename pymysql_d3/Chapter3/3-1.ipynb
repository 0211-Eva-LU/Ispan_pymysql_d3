# %%
import pymysql
from configparser import ConfigParser

config = ConfigParser()
config.read('../Chapter1/config.ini')

connection = pymysql.connect(
    host=config.get('DB', 'host'),
    user=config.get('DB', 'user'),
    password=config.get('DB', 'password'),
    port=config.getint('DB', 'port'),
    cursorclass=pymysql.cursors.DictCursor,
)

# 建立資料庫
with connection.cursor() as cursor:
    sql = """
    CREATE DATABASE IF NOT EXISTS chapter3;
    """
    cursor.execute(sql)

connection = pymysql.connect(
    host=config.get('DB', 'host'),
    user=config.get('DB', 'user'),
    password=config.get('DB', 'password'),
    port=config.getint('DB', 'port'),
    cursorclass=pymysql.cursors.DictCursor,
    db='chapter3',
)

# 建立有時間紀錄的表格
with connection.cursor() as cursor:
    sql = """
        CREATE TABLE IF NOT EXISTS user (
            id INT AUTO_INCREMENT PRIMARY KEY,
            name VARCHAR(255) NOT NULL,
            age INT,
            username VARCHAR(255) NOT NULL UNIQUE,
            password VARCHAR(255) NOT NULL,
            last_login TIMESTAMP DEFAULT CURRENT_TIMESTAMP
        );
    """
    cursor.execute(sql)
    cursor.execute("SHOW TABLES;")
    result = cursor.fetchall()

print(result)
# Out:
# [{'Tables_in_chapter3': 'user'}]

# %%
from pprint import pprint
with connection.cursor() as cursor:
    sql = """
    INSERT INTO user (name,age,username,password)
    VALUES ('Eva',27,'eva0211','aa123456')
    """
    cursor.execute(sql)
    connection.commit()
    cursor.execute("SELECT * FROM user;")
    result = cursor.fetchall()
pprint(result)
# Out:
# [{'age': 27,
#   'id': 1,
#   'last_login': datetime.datetime(2025, 12, 8, 9, 15, 39),
#   'name': 'Eva',
#   'password': 'aa123456',
#   'username': 'eva0211'}]

# %%
from datetime import datetime

# 取得當前時間
print(datetime.now())


# 取得指定時間的 datetime 物件
print(datetime(2025, 10, 10, 10, 10))

# 輸出成指定格式
now = datetime.now()
print(now.strftime("%Y/%m/%d %H:%M:%S")) #解析日期格式


# 取得民國年
now =datetime.now()
print(now.year)
print(now.month)
print(now.day)
print(f'民國年{now.year-1911}年')
# Out:
# 2025-12-08 09:32:31.524730
# 2025-10-10 10:10:00
# 2025/12/08 09:32:31
# 2025
# 12
# 8
# 民國年114年

# %%
# 將指定格式的字串轉換成 datetime 物件
from datetime import datetime
data_time = "2025/11/8 15-11-30"
# 轉換成 datetime 物件
time_format = datetime.strptime(data_time,"%Y/%m/%d %H-%M-%S")
print(time_format)
# Out:
# 2025-11-08 15:11:30

# %%
import pymysql
from configparser import ConfigParser

config = ConfigParser()
config.read('../Chapter1/config.ini')

connection = pymysql.connect(
    host=config.get('DB', 'host'),
    user=config.get('DB', 'user'),
    password=config.get('DB', 'password'),
    port=config.getint('DB', 'port'),
    cursorclass=pymysql.cursors.DictCursor,
)

# 建立資料庫
with connection.cursor() as cursor:
    sql = """
    CREATE DATABASE IF NOT EXISTS chapter3;
    """
    cursor.execute(sql)

connection = pymysql.connect(
    host=config.get('DB', 'host'),
    user=config.get('DB', 'user'),
    password=config.get('DB', 'password'),
    port=config.getint('DB', 'port'),
    cursorclass=pymysql.cursors.DictCursor,
    database='chapter3',
)


# 建立有時間紀錄的表格
with connection.cursor() as cursor:
    sql = """
        CREATE TABLE IF NOT EXISTS user2 (
            id INT AUTO_INCREMENT PRIMARY KEY,
            name VARCHAR(255) NOT NULL,
            age INT,
            username VARCHAR(255) NOT NULL UNIQUE,
            password VARCHAR(255) NOT NULL,
            start_date DATE DEFAULT NULL,
            last_login TIMESTAMP DEFAULT CURRENT_TIMESTAMP
        );
    """
    cursor.execute(sql)
    cursor.execute("SHOW TABLES;")
    result = cursor.fetchall()

print(result)
# Out:
# [{'Tables_in_chapter3': 'user'}, {'Tables_in_chapter3': 'user2'}]

# %%
from pprint import pprint
from datetime import datetime
with connection.cursor() as cursor:
    sql = """
    INSERT INTO user2 (name,age,username,password,start_date,last_login)
    VALUES ('Eva',27,'eva0211','aa123456',%s,%s)
    """
    cursor.execute(sql,("2025-11-01 09:00:00",now))
    connection.commit()
    cursor.execute("SELECT * FROM user2;")
    result = cursor.fetchall()
pprint(result)
# Out:
# [{'age': 27,
#   'id': 1,
#   'last_login': datetime.datetime(2025, 12, 8, 9, 32, 32),
#   'name': 'Eva',
#   'password': 'aa123456',
#   'start_date': datetime.date(2025, 11, 1),
#   'username': 'eva0211'}]

# %%
# 取得前一天日期
